# %%
# Let's make this notebook compatible for Python 2 and 3
from __future__ import division, print_function

# Import libraries
import pandas as pd
import numpy as np
import os
import math
import itertools
import string

# for visualization
import matplotlib.pyplot as plt

# to import module from parent directory
import sys
sys.path.append('..')

# Dataset API from sklearn
from sklearn import datasets

# %%
from utils import normalize, euclidean_distance, calculate_covariance_matrix, Plot

from deep_learning.optimizers import Adam
from deep_learning.loss_functions import CrossEntropy, SquareLoss
from deep_learning.layers import Dense, Dropout, Flatten, Activation, Reshape, BatchNormalization 
from deep_learning.neural_network import NeuralNetwork

# %%
class GeneticAlgorithm():
    """An implementation of a Genetic Algorithm which will try to produce the user
    specified target string.

    Parameters:
    -----------
    target_string: string
        The string which the GA should try to produce.
    population_size: int
        The number of individuals (possible solutions) in the population.
    mutation_rate: float
        The rate (or probability) of which the alleles (chars in this case) should be
        randomly changed.
    """
    def __init__(self, target_string, population_size, mutation_rate):
        self.target = target_string
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.letters = [" "] + list(string.ascii_letters)

    def _initialize(self):
        """ Initialize population with random strings """
        self.population = []
        for _ in range(self.population_size):
            # Select random letters as new individual
            individual = "".join(np.random.choice(self.letters, size=len(self.target)))
            self.population.append(individual)

    def _calculate_fitness(self):
        """ Calculates the fitness of each individual in the population """
        population_fitness = []
        for individual in self.population:
            # Calculate loss as the alphabetical distance between
            # the characters in the individual and the target string
            loss = 0
            for i in range(len(individual)):
                letter_i1 = self.letters.index(individual[i])
                letter_i2 = self.letters.index(self.target[i])
                loss += abs(letter_i1 - letter_i2)
            fitness = 1 / (loss + 1e-6)
            population_fitness.append(fitness)
        return population_fitness

    def _mutate(self, individual):
        """ Randomly change the individual's characters with probability
        self.mutation_rate """
        individual = list(individual)
        for j in range(len(individual)):
            # Make change with probability mutation_rate
            if np.random.random() < self.mutation_rate:
                individual[j] = np.random.choice(self.letters)
        # Return mutated individual as string
        return "".join(individual)

    def _crossover(self, parent1, parent2):
        """ Create children from parents by crossover """
        # Select random crossover point
        cross_i = np.random.randint(0, len(parent1))
        child1 = parent1[:cross_i] + parent2[cross_i:]
        child2 = parent2[:cross_i] + parent1[cross_i:]
        return child1, child2

    def run(self, iterations):
        # Initialize new population
        self._initialize()

        for epoch in range(iterations):
            population_fitness = self._calculate_fitness()

            fittest_individual = self.population[np.argmax(population_fitness)]
            highest_fitness = max(population_fitness)

            # If we have found individual which matches the target => Done
            if fittest_individual == self.target:
                break

            # Set the probability that the individual should be selected as a parent
            # proportionate to the individual's fitness.
            parent_probabilities = [fitness / sum(population_fitness) for fitness in population_fitness]

            # Determine the next generation
            new_population = []
            for i in np.arange(0, self.population_size, 2):
                # Select two parents randomly according to probabilities
                parent1, parent2 = np.random.choice(self.population, size=2, p=parent_probabilities, replace=False)
                # Perform crossover to produce offspring
                child1, child2 = self._crossover(parent1, parent2)
                # Save mutated offspring for next generation
                new_population += [self._mutate(child1), self._mutate(child2)]

            print ("[%d Closest Candidate: '%s', Fitness: %.2f]" % (epoch, fittest_individual, highest_fitness))
            self.population = new_population

        print ("[%d Answer: '%s']" % (epoch, fittest_individual))

# %%
def main():
    target_string = "Genetic Algorithm"
    population_size = 100
    mutation_rate = 0.05
    genetic_algorithm = GeneticAlgorithm(target_string,
                                        population_size,
                                        mutation_rate)

    print ("")
    print ("+--------+")
    print ("|   GA   |")
    print ("+--------+")
    print ("Description: Implementation of a Genetic Algorithm which aims to produce")
    print ("the user specified target string. This implementation calculates each")
    print ("candidate's fitness based on the alphabetical distance between the candidate")
    print ("and the target. A candidate is selected as a parent with probabilities proportional")
    print ("to the candidate's fitness. Reproduction is implemented as a single-point")
    print ("crossover between pairs of parents. Mutation is done by randomly assigning")
    print ("new characters with uniform probability.")
    print ("")
    print ("Parameters")
    print ("----------")
    print ("Target String: '%s'" % target_string)
    print ("Population Size: %d" % population_size)
    print ("Mutation Rate: %s" % mutation_rate)
    print ("")

    genetic_algorithm.run(iterations=1000)

if __name__ == "__main__":
    main()
# Out:
# +--------+
# |   GA   |
# +--------+
# Description: Implementation of a Genetic Algorithm which aims to produce
# the user specified target string. This implementation calculates each
# candidate's fitness based on the alphabetical distance between the candidate
# and the target. A candidate is selected as a parent with probabilities proportional
# to the candidate's fitness. Reproduction is implemented as a single-point
# crossover between pairs of parents. Mutation is done by randomly assigning
# new characters with uniform probability.
#
# Parameters
# ----------
# Target String: 'Genetic Algorithm'
# Population Size: 100
# Mutation Rate: 0.05
#
# [0 Closest Candidate: 'OjkBApedsxEfsximi', Fitness: 0.01]
# [1 Closest Candidate: 'EjiVvcbpxBduDxLik', Fitness: 0.01]
# [2 Closest Candidate: 'dxmhwznHvqcuupuAi', Fitness: 0.01]
# [3 Closest Candidate: 'EjiVquRJvqcuupuAi', Fitness: 0.00]
# [4 Closest Candidate: 'AweSRGdjHezhxgplh', Fitness: 0.01]
# [5 Closest Candidate: 'HcTKojdjHezhxgplh', Fitness: 0.01]
# [6 Closest Candidate: 'Fji vddjHezFxgplh', Fitness: 0.01]
# [7 Closest Candidate: 'Fji vddjHezFxgjCh', Fitness: 0.01]
# [8 Closest Candidate: 'Fji vddjHizFxgjCh', Fitness: 0.01]
# [9 Closest Candidate: 'Hclfvctemqcutpqoo', Fitness: 0.01]
# [10 Closest Candidate: 'Fji vddjHiOfgpfio', Fitness: 0.01]
# [11 Closest Candidate: 'Fji vctemdcutpqoo', Fitness: 0.01]
# [12 Closest Candidate: 'Hclfvdnjrecuwpumj', Fitness: 0.01]
# [13 Closest Candidate: 'Fji t djQunuwpumj', Fitness: 0.01]
# [14 Closest Candidate: 'HclfvdneEecuwpumL', Fitness: 0.01]
# [15 Closest Candidate: 'HclfvdneEkcuwpuQj', Fitness: 0.01]
# [16 Closest Candidate: 'HclfvdneEkcuwsumx', Fitness: 0.01]
# [17 Closest Candidate: 'KclfvdneEkcuwsumx', Fitness: 0.01]
# [18 Closest Candidate: 'KclfvdneEkcuwsumx', Fitness: 0.01]
# [19 Closest Candidate: 'Hci tmbeEkcuwsumx', Fitness: 0.01]
# [20 Closest Candidate: 'HclfvddjHdcutpqlx', Fitness: 0.01]
# [21 Closest Candidate: 'Hci tmbjEetuwpuoo', Fitness: 0.01]
# [22 Closest Candidate: 'HclfvgfjHdcttpqoo', Fitness: 0.01]
# [23 Closest Candidate: 'HclfvgfjHdcttpqoo', Fitness: 0.01]
# [24 Closest Candidate: 'FclfvgfjHdcttpqoo', Fitness: 0.01]
# [25 Closest Candidate: 'HclfvdfjHdqotpulo', Fitness: 0.01]
# [26 Closest Candidate: 'AclfvdfjHdqotpulo', Fitness: 0.01]
# [27 Closest Candidate: 'DclfvgfjHdetCpuoo', Fitness: 0.01]
# [28 Closest Candidate: 'HclfvgfjHdcutiump', Fitness: 0.02]
# [29 Closest Candidate: 'AjlfvgfjHsettiuoo', Fitness: 0.02]
# [30 Closest Candidate: 'Hcgfvg aHdcvtkumq', Fitness: 0.02]
# [31 Closest Candidate: 'HclfvdieEdcytkumq', Fitness: 0.02]
# [32 Closest Candidate: 'FclfngfeFkcttpqoq', Fitness: 0.02]
# [33 Closest Candidate: 'HclfvgbeFkcuwpuou', Fitness: 0.02]
# [34 Closest Candidate: 'HclfzgbeFkcstpuoo', Fitness: 0.02]
# [35 Closest Candidate: 'HclfvgbeFkcuwpuoo', Fitness: 0.02]
# [36 Closest Candidate: 'HclfvgfeFkcjwpuoo', Fitness: 0.02]
# [37 Closest Candidate: 'HclfzgbeFkcwtivoo', Fitness: 0.02]
# [38 Closest Candidate: 'DclfvgfeEseqtpuoo', Fitness: 0.02]
# [39 Closest Candidate: 'HclfzgbeFkeqtpuoo', Fitness: 0.02]
# [40 Closest Candidate: 'KclfzgbeFkeqtpuoo', Fitness: 0.02]
# [41 Closest Candidate: 'Hclfvgfewkkwwiqmo', Fitness: 0.02]
# [42 Closest Candidate: 'Hclfvgfewkcptpuoq', Fitness: 0.02]
# [43 Closest Candidate: 'Holfvgfewkcptpuoo', Fitness: 0.02]
# [44 Closest Candidate: 'Hclfvgfetdlqmpulo', Fitness: 0.02]
# [45 Closest Candidate: 'Hclfvgfetdlqmpulo', Fitness: 0.02]
# [46 Closest Candidate: 'HclfvgfeEkdwtpuoo', Fitness: 0.02]
# [47 Closest Candidate: 'HclfvgfeFkdwtpuoj', Fitness: 0.02]
# [48 Closest Candidate: 'GclfvjaeFndBtiuog', Fitness: 0.02]
# [49 Closest Candidate: 'HclfljdeFndBtiuog', Fitness: 0.02]
# [50 Closest Candidate: 'HclfljdeFndBtiuog', Fitness: 0.02]
# [51 Closest Candidate: 'HclfvafeFkeqtiuro', Fitness: 0.02]
# [52 Closest Candidate: 'HclfvafeFkdctiulo', Fitness: 0.02]
# [53 Closest Candidate: 'Hdlfvgfexgdqtiulo', Fitness: 0.03]
# [54 Closest Candidate: 'Hdlfvgfexgdqtiuio', Fitness: 0.03]
# [55 Closest Candidate: 'HclfngbeSkdtniuio', Fitness: 0.02]
# [56 Closest Candidate: 'HclftgbeSkdtniuiq', Fitness: 0.02]
# [57 Closest Candidate: 'Lclfvgbexgdwsgurq', Fitness: 0.02]
# [58 Closest Candidate: 'Hflfvjaetdnqtiuoi', Fitness: 0.02]
# [59 Closest Candidate: 'Qclfvgfexdkqtiuoi', Fitness: 0.02]
# [60 Closest Candidate: 'Hclfvgfeznddtpzho', Fitness: 0.02]
# [61 Closest Candidate: 'Hllfvgfexdkqtiuiq', Fitness: 0.02]
# [62 Closest Candidate: 'HflfvjdeSkdtsiuiq', Fitness: 0.02]
# [63 Closest Candidate: 'Hclfvgfeznddtpzho', Fitness: 0.02]
# [64 Closest Candidate: 'Hclfvgfeznddtpzko', Fitness: 0.02]
# [65 Closest Candidate: 'Gclftgbezeddtpzho', Fitness: 0.02]
# [66 Closest Candidate: 'Dclfvgfgzeddtgzho', Fitness: 0.02]
# [67 Closest Candidate: 'Milfvgfexkddtpzho', Fitness: 0.02]
# [68 Closest Candidate: 'HclfCgfexkddtpuio', Fitness: 0.02]
# [69 Closest Candidate: 'HcnftgbeRkdntiuiu', Fitness: 0.02]
# [70 Closest Candidate: 'HclftgbeRkdntiuiu', Fitness: 0.02]
# [71 Closest Candidate: 'HcufukcezBdqtguiq', Fitness: 0.02]
# [72 Closest Candidate: 'Hclfvgfexkdqnpyko', Fitness: 0.02]
# [73 Closest Candidate: 'Hclfvgfexkdqnpyho', Fitness: 0.02]
# [74 Closest Candidate: 'Hclfvgfezkdwtpzko', Fitness: 0.02]
# [75 Closest Candidate: 'Hcofvgfezkdwtpzko', Fitness: 0.02]
# [76 Closest Candidate: 'Hclftafexnddtgufq', Fitness: 0.02]
# [77 Closest Candidate: 'HclfIjfbzndntivao', Fitness: 0.02]
# [78 Closest Candidate: 'Milfukcexgdqpgufo', Fitness: 0.02]
# [79 Closest Candidate: 'Hclfsgfqzkdntivao', Fitness: 0.02]
# [80 Closest Candidate: 'Hclfsgfqzkdqnpzko', Fitness: 0.02]
# [81 Closest Candidate: 'Hclfsgfqzkdqnguao', Fitness: 0.02]
# [82 Closest Candidate: 'Hcefvgeaxniqcguiq', Fitness: 0.02]
# [83 Closest Candidate: 'Gclfvfiezkddtgufp', Fitness: 0.02]
# [84 Closest Candidate: 'Gdlfvgeaxniqcguiq', Fitness: 0.02]
# [85 Closest Candidate: 'Fcllvgeaxnistgyim', Fitness: 0.02]
# [86 Closest Candidate: 'Gdlfvgeaxnddtpyim', Fitness: 0.02]
# [87 Closest Candidate: 'Gdlfvgeaxniqcguiq', Fitness: 0.02]
# [88 Closest Candidate: 'Gflfvmfazniqcguiq', Fitness: 0.02]
# [89 Closest Candidate: 'Gflfvmfazniqtggfp', Fitness: 0.02]
# [90 Closest Candidate: 'Gflfvmfazniqtgyio', Fitness: 0.03]
# [91 Closest Candidate: 'HclfGjeaxnistgsip', Fitness: 0.02]
# [92 Closest Candidate: 'BcedvgeaxnistgAiq', Fitness: 0.02]
# [93 Closest Candidate: 'Gcldvfiezknotgwfp', Fitness: 0.02]
# [94 Closest Candidate: 'Hcldvfiaxmiotgwfp', Fitness: 0.03]
# [95 Closest Candidate: 'Hcldvfiaxmiotgwfp', Fitness: 0.03]
# [96 Closest Candidate: 'Hcldvfiazmiqtgstp', Fitness: 0.02]
# [97 Closest Candidate: 'HcldvfeaNnistgwfp', Fitness: 0.02]
# [98 Closest Candidate: 'HclfzgeazniotgEfp', Fitness: 0.02]
# [99 Closest Candidate: 'QclfvgeeAndstgsip', Fitness: 0.02]
# [100 Closest Candidate: 'Hcldvfiazkdotgsiq', Fitness: 0.03]
# [101 Closest Candidate: 'GcldvjeeAndstgsip', Fitness: 0.03]
# [102 Closest Candidate: 'Hcldvfiazkdotgsiq', Fitness: 0.03]
# [103 Closest Candidate: 'Hhlfvgeezmiotgtfp', Fitness: 0.03]
# [104 Closest Candidate: 'HcldvjeeAndttgyiq', Fitness: 0.02]
# [105 Closest Candidate: 'Gcedvfiezkdotgsin', Fitness: 0.02]
# [106 Closest Candidate: 'Gcldvjeezkdongyin', Fitness: 0.03]
# [107 Closest Candidate: 'Gcldvjeezkdongyin', Fitness: 0.03]
# [108 Closest Candidate: 'Gcldvjeezkdongyin', Fitness: 0.03]
# [109 Closest Candidate: 'GcldvjeaBkiotgulp', Fitness: 0.04]
# [110 Closest Candidate: 'Gcldvfiayndspgyin', Fitness: 0.03]
# [111 Closest Candidate: 'Hildvjeezkiongyip', Fitness: 0.03]
# [112 Closest Candidate: 'GcldvjeaAkdongyin', Fitness: 0.04]
# [113 Closest Candidate: 'HcmdvjeaAkdongyin', Fitness: 0.04]
# [114 Closest Candidate: 'GcldvjeeAkdongyin', Fitness: 0.03]
# [115 Closest Candidate: 'GcldvjeeEkdttgufp', Fitness: 0.03]
# [116 Closest Candidate: 'GsldvjeeAkdongyin', Fitness: 0.02]
# [117 Closest Candidate: 'GcndvjeeEkdttgnip', Fitness: 0.02]
# [118 Closest Candidate: 'GildvjeaxkdoBgyiq', Fitness: 0.02]
# [119 Closest Candidate: 'GcmdvjeazkdstgDip', Fitness: 0.03]
# [120 Closest Candidate: 'GcmdzjeazkdstgDip', Fitness: 0.02]
# [121 Closest Candidate: 'Gcofvjbaxkdongyfg', Fitness: 0.03]
# [122 Closest Candidate: 'GcofvjbaGkcgtilfk', Fitness: 0.02]
# [123 Closest Candidate: 'GcofvjbaGkcgtilfk', Fitness: 0.02]
# [124 Closest Candidate: 'GcndvjeavkdoriFfk', Fitness: 0.03]
# [125 Closest Candidate: 'GcndvjedAkdongyfg', Fitness: 0.03]
# [126 Closest Candidate: 'GcndvjedAkdongyfk', Fitness: 0.03]
# [127 Closest Candidate: 'GcndvjedAkdongyfg', Fitness: 0.03]
# [128 Closest Candidate: 'Gcndvjbazjdonilan', Fitness: 0.03]
# [129 Closest Candidate: 'Gcndtjbazjdonilan', Fitness: 0.03]
# [130 Closest Candidate: 'Gcndvhbazjdoniuip', Fitness: 0.04]
# [131 Closest Candidate: 'GcndvjeezndoBgtiq', Fitness: 0.03]
# [132 Closest Candidate: 'Gfldvjdazjdonilan', Fitness: 0.03]
# [133 Closest Candidate: 'ScndvjeaAncsnitiq', Fitness: 0.02]
# [134 Closest Candidate: 'GcndvceeCqdokguin', Fitness: 0.02]
# [135 Closest Candidate: 'GcndpjeaCqdokguin', Fitness: 0.03]
# [136 Closest Candidate: 'Gcndvjdavjdonisan', Fitness: 0.03]
# [137 Closest Candidate: 'Gcndvjdavjdokguin', Fitness: 0.03]
# [138 Closest Candidate: 'Gcndvjdavjdokguin', Fitness: 0.03]
# [139 Closest Candidate: 'Gcjdvjdavjdonitim', Fitness: 0.04]
# [140 Closest Candidate: 'Gcjdvjdavjdonitim', Fitness: 0.04]
# [141 Closest Candidate: 'Gcndvjdavjdosiujp', Fitness: 0.04]
# [142 Closest Candidate: 'Gcndvjdavjdosiujp', Fitness: 0.04]
# [143 Closest Candidate: 'Gcndvjbazjdonitim', Fitness: 0.05]
# [144 Closest Candidate: 'Gcndvjbazjdonitin', Fitness: 0.05]
# [145 Closest Candidate: 'Gcndvjbazjdoniuin', Fitness: 0.05]
# [146 Closest Candidate: 'Genduodbzjdonitin', Fitness: 0.04]
# [147 Closest Candidate: 'Gcndvjbazjdonitin', Fitness: 0.05]
# [148 Closest Candidate: 'Ccndvjbazjdoniuin', Fitness: 0.04]
# [149 Closest Candidate: 'Genduo azjdoniuin', Fitness: 0.04]
# [150 Closest Candidate: 'Ccndvjbazjdoniuin', Fitness: 0.04]
# [151 Closest Candidate: 'Genduo azjdotguin', Fitness: 0.04]
# [152 Closest Candidate: 'CcndvjbaGldotguin', Fitness: 0.04]
# [153 Closest Candidate: 'GcndvobaCjjonguin', Fitness: 0.03]
# [154 Closest Candidate: 'GcndvjbaJjdotgugn', Fitness: 0.03]
# [155 Closest Candidate: 'Gcndvebazldonisam', Fitness: 0.04]
# [156 Closest Candidate: 'Gcndvebazldonkson', Fitness: 0.03]
# [157 Closest Candidate: 'GcndvodaGldmtguin', Fitness: 0.03]
# [158 Closest Candidate: 'GcndvjbaCjdotguin', Fitness: 0.05]
# [159 Closest Candidate: 'GcndvjbaCjdotguin', Fitness: 0.05]
# [160 Closest Candidate: 'GcndvjbaCjdotguin', Fitness: 0.05]
# [161 Closest Candidate: 'GcndvjbaCjdorguik', Fitness: 0.05]
# [162 Closest Candidate: 'GcndundaGldmoiuin', Fitness: 0.04]
# [163 Closest Candidate: 'GhndvjbaCjdoohuik', Fitness: 0.04]
# [164 Closest Candidate: 'GcndvjbaCjdoohuik', Fitness: 0.04]
# [165 Closest Candidate: 'GcndvjhaCjdoohuik', Fitness: 0.04]
# [166 Closest Candidate: 'GkndvjbaGidorguik', Fitness: 0.03]
# [167 Closest Candidate: 'GcndvjbaJjdorguim', Fitness: 0.04]
# [168 Closest Candidate: 'GcndvjbaJjdorguim', Fitness: 0.04]
# [169 Closest Candidate: 'GcndvjgaCkdotguin', Fitness: 0.04]
# [170 Closest Candidate: 'GcndvjgaCkdotguin', Fitness: 0.04]
# [171 Closest Candidate: 'GcndvjgaCjcotguin', Fitness: 0.04]
# [172 Closest Candidate: 'GcndvjgaCidorguik', Fitness: 0.04]
# [173 Closest Candidate: 'GcndvjgaCjaorguik', Fitness: 0.04]
# [174 Closest Candidate: 'GcndvjbaGidorguin', Fitness: 0.04]
# [175 Closest Candidate: 'GcndvjbaJjdotiuik', Fitness: 0.04]
# [176 Closest Candidate: 'GcndvjbaJjdotiuik', Fitness: 0.04]
# [177 Closest Candidate: 'Gcndvjbavldotiwim', Fitness: 0.05]
# [178 Closest Candidate: 'GcndujbaJjdotiuik', Fitness: 0.04]
# [179 Closest Candidate: 'Gcndvjbavldotiuik', Fitness: 0.05]
# [180 Closest Candidate: 'Gfndvjbayjbnrgsik', Fitness: 0.04]
# [181 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [182 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [183 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [184 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [185 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [186 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [187 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [188 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [189 Closest Candidate: 'Gcndujcayjdnriuim', Fitness: 0.06]
# [190 Closest Candidate: 'Gcndujcayjdnriuim', Fitness: 0.06]
# [191 Closest Candidate: 'Gcndvjbayjdnriuim', Fitness: 0.06]
# [192 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [193 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [194 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [195 Closest Candidate: 'Gcndujbayjdotiuim', Fitness: 0.06]
# [196 Closest Candidate: 'GcndvjbaAjdoriuik', Fitness: 0.06]
# [197 Closest Candidate: 'Gcndvjbayjdnriuim', Fitness: 0.06]
# [198 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [199 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [200 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [201 Closest Candidate: 'Gcndujbayjdnrisim', Fitness: 0.06]
# [202 Closest Candidate: 'Gcndujbayjdnriuik', Fitness: 0.05]
# [203 Closest Candidate: 'Gcndvjbayjcoriuim', Fitness: 0.06]
# [204 Closest Candidate: 'Gcndujbayjeorivfk', Fitness: 0.05]
# [205 Closest Candidate: 'Gcodujbayjcoriuim', Fitness: 0.06]
# [206 Closest Candidate: 'Gcndujbayjcoriuim', Fitness: 0.06]
# [207 Closest Candidate: 'Gcndsjbayjcoriuim', Fitness: 0.06]
# [208 Closest Candidate: 'Gcndvjbayjcoriuim', Fitness: 0.06]
# [209 Closest Candidate: 'Gendujaayoinrixim', Fitness: 0.05]
# [210 Closest Candidate: 'Gcndujbayjdnriuim', Fitness: 0.06]
# [211 Closest Candidate: 'Gcndujbayjdoriuhm', Fitness: 0.07]
# [212 Closest Candidate: 'Gcndujbayjdoriuim', Fitness: 0.06]
# [213 Closest Candidate: 'GendujbaAjcmriuim', Fitness: 0.07]
# [214 Closest Candidate: 'Gdndqjbayjdoriuhm', Fitness: 0.06]
# [215 Closest Candidate: 'Gcldvjbayjcoriuim', Fitness: 0.05]
# [216 Closest Candidate: 'Gcndvjbayjdoriuhm', Fitness: 0.06]
# [217 Closest Candidate: 'Gcndvjbayjcoriuim', Fitness: 0.06]
# [218 Closest Candidate: 'Gcndvjbayjcoriuhm', Fitness: 0.06]
# [219 Closest Candidate: 'Gendujbayjdoriuhm', Fitness: 0.08]
# [220 Closest Candidate: 'Gendujbayjcmriuim', Fitness: 0.06]
# [221 Closest Candidate: 'Gcndvjb Ajcoriuim', Fitness: 0.07]
# [222 Closest Candidate: 'Gcndvjbaylhoriuim', Fitness: 0.08]
# [223 Closest Candidate: 'Gcndvjbaylhoriuim', Fitness: 0.08]
# [224 Closest Candidate: 'Gcndvjbayjdoriuhm', Fitness: 0.06]
# [225 Closest Candidate: 'Gendvjb Ajcoriuim', Fitness: 0.08]
# [226 Closest Candidate: 'Gendvjb Ajcoriuim', Fitness: 0.08]
# [227 Closest Candidate: 'Gendvjbaylhoriuim', Fitness: 0.09]
# [228 Closest Candidate: 'Gendvjbaylhoriuhm', Fitness: 0.10]
# [229 Closest Candidate: 'Gendvjb ylhoriuhm', Fitness: 0.11]
# [230 Closest Candidate: 'Gendvjb ylhoriuim', Fitness: 0.10]
# [231 Closest Candidate: 'Gendvjb Alhoriuim', Fitness: 0.12]
# [232 Closest Candidate: 'Gendvjb Alhoriuim', Fitness: 0.12]
# [233 Closest Candidate: 'Gendvjb Alhoriuim', Fitness: 0.12]
# [234 Closest Candidate: 'Gendvjb Alhoriuim', Fitness: 0.12]
# [235 Closest Candidate: 'Gendvjb Alhoriuim', Fitness: 0.12]
# [236 Closest Candidate: 'Gendvjb Alhoriuim', Fitness: 0.12]
# [237 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [238 Closest Candidate: 'Gendvjb Alhoriuhm', Fitness: 0.14]
# [239 Closest Candidate: 'Gendsjb Alhoriuhm', Fitness: 0.17]
# [240 Closest Candidate: 'Gendvib Alhoriuim', Fitness: 0.14]
# [241 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [242 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [243 Closest Candidate: 'Gendvib Alhoriuhl', Fitness: 0.14]
# [244 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [245 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [246 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [247 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [248 Closest Candidate: 'Gendsib Amhoriuhm', Fitness: 0.17]
# [249 Closest Candidate: 'Gendvib Alhoriuhl', Fitness: 0.14]
# [250 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [251 Closest Candidate: 'Gendvib Amhoriuhm', Fitness: 0.14]
# [252 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [253 Closest Candidate: 'Gendvib Alhoriuim', Fitness: 0.14]
# [254 Closest Candidate: 'Gendvib Alhoriuim', Fitness: 0.14]
# [255 Closest Candidate: 'Gendvib Amhoriuhm', Fitness: 0.14]
# [256 Closest Candidate: 'Gendujb Alhoriuhm', Fitness: 0.17]
# [257 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [258 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [259 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [260 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [261 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [262 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [263 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [264 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [265 Closest Candidate: 'Gendujb Alhoriuhm', Fitness: 0.17]
# [266 Closest Candidate: 'Genduib Alhoriuhm', Fitness: 0.20]
# [267 Closest Candidate: 'Gendvib Alhoriuhm', Fitness: 0.17]
# [268 Closest Candidate: 'Gendtib Alhoriuim', Fitness: 0.20]
# [269 Closest Candidate: 'Gendtib Alhoriuim', Fitness: 0.20]
# [270 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [271 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [272 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [273 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [274 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [275 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [276 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [277 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [278 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [279 Closest Candidate: 'Gendtib Alhoriuhm', Fitness: 0.25]
# [280 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [281 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [282 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [283 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [284 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [285 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [286 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [287 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [288 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [289 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [290 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [291 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [292 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [293 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [294 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [295 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [296 Closest Candidate: 'Gendtib Alhorithm', Fitness: 0.33]
# [297 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [298 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [299 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [300 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [301 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [302 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [303 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [304 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [305 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [306 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [307 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [308 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [309 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [310 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [311 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [312 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [313 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [314 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [315 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [316 Closest Candidate: 'Genetib Akgorithm', Fitness: 0.50]
# [317 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [318 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [319 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [320 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [321 Closest Candidate: 'Genetib Alhorithm', Fitness: 0.50]
# [322 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [323 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [324 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [325 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [326 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [327 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [328 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [329 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [330 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [331 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [332 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [333 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [334 Closest Candidate: 'Genetic Alforithm', Fitness: 1.00]
# [335 Closest Candidate: 'Genetic Alhorithm', Fitness: 1.00]
# [336 Closest Candidate: 'Genetic Alforithm', Fitness: 1.00]
# [337 Answer: 'Genetic Algorithm']
