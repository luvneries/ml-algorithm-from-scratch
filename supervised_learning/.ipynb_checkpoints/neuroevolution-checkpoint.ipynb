# %%
# Let's make this notebook compatible for Python 2 and 3
from __future__ import division, print_function

# Import libraries
import pandas as pd
import numpy as np
import os
import math
import copy

# for visualization
import matplotlib.pyplot as plt

# to import module from parent directory
import sys
sys.path.append('..')

# Dataset API from sklearn
from sklearn import datasets

# %%
# Import helper functions
from utils import Plot, accuracy_score, train_test_split
from utils import to_categorical, normalize

from deep_learning.neural_network import NeuralNetwork
from deep_learning.layers import Activation, Dense
from deep_learning.optimizers import Adam
from deep_learning.loss_functions import CrossEntropy

# %%
class Neuroevolution():
    """ Evolutionary optimization of Neural Networks.

    Parameters:
    -----------
    n_individuals: int
        The number of neural networks that are allowed in the population at a time.
    mutation_rate: float
        The probability that a weight will be mutated.
    model_builder: method
        A method which returns a user specified NeuralNetwork instance. 
    """
    def __init__(self, population_size, mutation_rate, model_builder):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_builder = model_builder

    def _build_model(self, id):
        """ Returns a new individual """
        model = self.model_builder(n_inputs=self.X.shape[1], n_outputs=self.y.shape[1])
        model.id = id
        model.fitness = 0
        model.accuracy = 0
        
        return model

    def _initialize_population(self):
        """ Initialization of the neural networks forming the population"""
        self.population = []
        for _ in range(self.population_size):
            model = self._build_model(id=np.random.randint(1000))
            self.population.append(model)

    def _mutate(self, individual, var=1):
        """ Add zero mean gaussian noise to the layer weights with probability mutation_rate """
        for layer in individual.layers:
            if hasattr(layer, 'W'):
                # Mutation of weight with probability self.mutation_rate
                mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=layer.W.shape)
                layer.W += np.random.normal(loc=0, scale=var, size=layer.W.shape) * mutation_mask
                mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=layer.w0.shape)
                layer.w0 += np.random.normal(loc=0, scale=var, size=layer.w0.shape) * mutation_mask
        
        return individual

    def _inherit_weights(self, child, parent):
        """ Copies the weights from parent to child """
        for i in range(len(child.layers)):
            if hasattr(child.layers[i], 'W'):
                # The child inherits both weights W and bias weights w0
                child.layers[i].W = parent.layers[i].W.copy()
                child.layers[i].w0 = parent.layers[i].w0.copy()

    def _crossover(self, parent1, parent2):
        """ Performs crossover between the neurons in parent1 and parent2 to form offspring """
        child1 = self._build_model(id=parent1.id+1)
        self._inherit_weights(child1, parent1)
        child2 = self._build_model(id=parent2.id+1)
        self._inherit_weights(child2, parent2)

        # Perform crossover
        for i in range(len(child1.layers)):
            if hasattr(child1.layers[i], 'W'):
                n_neurons = child1.layers[i].W.shape[1]
                # Perform crossover between the individuals' neuron weights
                cutoff = np.random.randint(0, n_neurons)
                child1.layers[i].W[:, cutoff:] = parent2.layers[i].W[:, cutoff:].copy()
                child1.layers[i].w0[:, cutoff:] = parent2.layers[i].w0[:, cutoff:].copy()
                child2.layers[i].W[:, cutoff:] = parent1.layers[i].W[:, cutoff:].copy()
                child2.layers[i].w0[:, cutoff:] = parent1.layers[i].w0[:, cutoff:].copy()
        
        return child1, child2

    def _calculate_fitness(self):
        """ Evaluate the NNs on the test set to get fitness scores """
        for individual in self.population:
            loss, acc = individual.test_on_batch(self.X, self.y)
            individual.fitness = 1 / (loss + 1e-8)
            individual.accuracy = acc

    def evolve(self, X, y, n_generations):
        """ Will evolve the population for n_generations based on dataset X and labels y"""
        self.X, self.y = X, y

        self._initialize_population()

        # The 40% highest fittest individuals will be selected for the next generation
        n_winners = int(self.population_size * 0.4)
        # The fittest 60% of the population will be selected as parents to form offspring
        n_parents = self.population_size - n_winners

        for epoch in range(n_generations):
            # Determine the fitness of the individuals in the population
            self._calculate_fitness()

            # Sort population by fitness
            sorted_i = np.argsort([model.fitness for model in self.population])[::-1]
            self.population = [self.population[i] for i in sorted_i]

            # Get the individual with the highest fitness
            fittest_individual = self.population[0]
            print ("[%d Best Individual - Fitness: %.5f, Accuracy: %.1f%%]" % (epoch, 
                                                                        fittest_individual.fitness, 
                                                                        float(100*fittest_individual.accuracy)))
            # The 'winners' are selected for the next generation
            next_population = [self.population[i] for i in range(n_winners)]

            total_fitness = np.sum([model.fitness for model in self.population])
            # The probability that a individual will be selected as a parent is proportionate to its fitness
            parent_probabilities = [model.fitness / total_fitness for model in self.population]
            # Select parents according to probabilities (without replacement to preserve diversity)
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            for i in np.arange(0, len(parents), 2):
                # Perform crossover to produce offspring
                child1, child2 = self._crossover(parents[i], parents[i+1])
                # Save mutated offspring for next population
                next_population += [self._mutate(child1), self._mutate(child2)]

            self.population = next_population

        return fittest_individual

# %%
def main():

    X, y = datasets.make_classification(n_samples=1000, n_features=10, n_classes=4, n_clusters_per_class=1, n_informative=2)

    data = datasets.load_digits()
    X = normalize(data.data)
    y = data.target
    y = to_categorical(y.astype("int"))

    # Model builder
    def model_builder(n_inputs, n_outputs):    
        model = NeuralNetwork(optimizer=Adam(), loss=CrossEntropy)
        model.add(Dense(16, input_shape=(n_inputs,)))
        model.add(Activation('relu'))
        model.add(Dense(n_outputs))
        model.add(Activation('softmax'))

        return model

    # Print the model summary of a individual in the population
    print ("")
    model_builder(n_inputs=X.shape[1], n_outputs=y.shape[1]).summary()

    population_size = 100
    n_generations = 3000
    mutation_rate = 0.01

    print ("Population Size: %d" % population_size)
    print ("Generations: %d" % n_generations)
    print ("Mutation Rate: %.2f" % mutation_rate)
    print ("")

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, seed=1)

    model = Neuroevolution(population_size=population_size, 
                        mutation_rate=mutation_rate, 
                        model_builder=model_builder)
    
    model = model.evolve(X_train, y_train, n_generations=n_generations)

    loss, accuracy = model.test_on_batch(X_test, y_test)

    # Reduce dimension to 2D using PCA and plot the results
    y_pred = np.argmax(model.predict(X_test), axis=1)
    Plot().plot_in_2d(X_test, y_pred, title="Evolutionary Evolved Neural Network", accuracy=accuracy, legend_labels=range(y.shape[1]))


if __name__ == "__main__":
    main()
# Out:
# +---------------+
# | Model Summary |
# +---------------+
# Input Shape: (64,)
# +----------------------+------------+--------------+
# | Layer Type           | Parameters | Output Shape |
# +----------------------+------------+--------------+
# | Dense                | 1040       | (16,)        |
# | Activation (ReLU)    | 0          | (16,)        |
# | Dense                | 170        | (10,)        |
# | Activation (Softmax) | 0          | (10,)        |
# +----------------------+------------+--------------+
# Total Parameters: 1210
#
# Population Size: 100
# Generations: 3000
# Mutation Rate: 0.01
#
# [0 Best Individual - Fitness: 3.08301, Accuracy: 10.5%]
# [1 Best Individual - Fitness: 3.08746, Accuracy: 12.0%]
# [2 Best Individual - Fitness: 3.08967, Accuracy: 19.6%]
# [3 Best Individual - Fitness: 3.11408, Accuracy: 16.2%]
# [4 Best Individual - Fitness: 3.11408, Accuracy: 16.2%]
# [5 Best Individual - Fitness: 3.11408, Accuracy: 16.2%]
# [6 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [7 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [8 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [9 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [10 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [11 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [12 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [13 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [14 Best Individual - Fitness: 3.13622, Accuracy: 17.2%]
# [15 Best Individual - Fitness: 3.15249, Accuracy: 12.5%]
# [16 Best Individual - Fitness: 3.15249, Accuracy: 12.5%]
# [17 Best Individual - Fitness: 3.15249, Accuracy: 12.5%]
# [18 Best Individual - Fitness: 3.15249, Accuracy: 12.5%]
# [19 Best Individual - Fitness: 3.18225, Accuracy: 23.0%]
# [20 Best Individual - Fitness: 3.18225, Accuracy: 23.0%]
# [21 Best Individual - Fitness: 3.18225, Accuracy: 23.0%]
# [22 Best Individual - Fitness: 3.18225, Accuracy: 23.0%]
# [23 Best Individual - Fitness: 3.18225, Accuracy: 23.0%]
# [24 Best Individual - Fitness: 3.18225, Accuracy: 23.0%]
# [25 Best Individual - Fitness: 3.19069, Accuracy: 19.9%]
# [26 Best Individual - Fitness: 3.19069, Accuracy: 19.9%]
# [27 Best Individual - Fitness: 3.19069, Accuracy: 19.9%]
# [28 Best Individual - Fitness: 3.19584, Accuracy: 21.9%]
# [29 Best Individual - Fitness: 3.19584, Accuracy: 21.9%]
# [30 Best Individual - Fitness: 3.21492, Accuracy: 15.8%]
# [31 Best Individual - Fitness: 3.22573, Accuracy: 21.4%]
# [32 Best Individual - Fitness: 3.22573, Accuracy: 21.4%]
# [33 Best Individual - Fitness: 3.23923, Accuracy: 24.3%]
# [34 Best Individual - Fitness: 3.23923, Accuracy: 24.3%]
# [35 Best Individual - Fitness: 3.28171, Accuracy: 24.6%]
# [36 Best Individual - Fitness: 3.28171, Accuracy: 24.6%]
# [37 Best Individual - Fitness: 3.30289, Accuracy: 32.5%]
# [38 Best Individual - Fitness: 3.30289, Accuracy: 32.5%]
# [39 Best Individual - Fitness: 3.34107, Accuracy: 26.4%]
# [40 Best Individual - Fitness: 3.34107, Accuracy: 26.4%]
# [41 Best Individual - Fitness: 3.35294, Accuracy: 24.3%]
# [42 Best Individual - Fitness: 3.35294, Accuracy: 24.3%]
# [43 Best Individual - Fitness: 3.35294, Accuracy: 24.3%]
# [44 Best Individual - Fitness: 3.35965, Accuracy: 28.9%]
# [45 Best Individual - Fitness: 3.35965, Accuracy: 28.9%]
# [46 Best Individual - Fitness: 3.36856, Accuracy: 25.4%]
# [47 Best Individual - Fitness: 3.36856, Accuracy: 25.4%]
# [48 Best Individual - Fitness: 3.38667, Accuracy: 28.1%]
# [49 Best Individual - Fitness: 3.38667, Accuracy: 28.1%]
# [50 Best Individual - Fitness: 3.39087, Accuracy: 28.5%]
# [51 Best Individual - Fitness: 3.40013, Accuracy: 29.8%]
# [52 Best Individual - Fitness: 3.40013, Accuracy: 29.8%]
# [53 Best Individual - Fitness: 3.44464, Accuracy: 22.4%]
# [54 Best Individual - Fitness: 3.44716, Accuracy: 31.5%]
# [55 Best Individual - Fitness: 3.44716, Accuracy: 31.5%]
# [56 Best Individual - Fitness: 3.44716, Accuracy: 31.5%]
# [57 Best Individual - Fitness: 3.44716, Accuracy: 31.5%]
# [58 Best Individual - Fitness: 3.45738, Accuracy: 31.7%]
# [59 Best Individual - Fitness: 3.48080, Accuracy: 31.7%]
# [60 Best Individual - Fitness: 3.48080, Accuracy: 31.7%]
# [61 Best Individual - Fitness: 3.48080, Accuracy: 31.7%]
# [62 Best Individual - Fitness: 3.48080, Accuracy: 31.7%]
# [63 Best Individual - Fitness: 3.49955, Accuracy: 34.8%]
# [64 Best Individual - Fitness: 3.51224, Accuracy: 32.9%]
# [65 Best Individual - Fitness: 3.51224, Accuracy: 32.9%]
# [66 Best Individual - Fitness: 3.51224, Accuracy: 32.9%]
# [67 Best Individual - Fitness: 3.55800, Accuracy: 30.5%]
# [68 Best Individual - Fitness: 3.55800, Accuracy: 30.5%]
# [69 Best Individual - Fitness: 3.56920, Accuracy: 29.4%]
# [70 Best Individual - Fitness: 3.59467, Accuracy: 35.6%]
# [71 Best Individual - Fitness: 3.59648, Accuracy: 34.5%]
# [72 Best Individual - Fitness: 3.59648, Accuracy: 34.5%]
# [73 Best Individual - Fitness: 3.60002, Accuracy: 35.8%]
# [74 Best Individual - Fitness: 3.60726, Accuracy: 31.8%]
# [75 Best Individual - Fitness: 3.60726, Accuracy: 31.8%]
# [76 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [77 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [78 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [79 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [80 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [81 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [82 Best Individual - Fitness: 3.67563, Accuracy: 37.3%]
# [83 Best Individual - Fitness: 3.73198, Accuracy: 38.9%]
# [84 Best Individual - Fitness: 3.73198, Accuracy: 38.9%]
# [85 Best Individual - Fitness: 3.73198, Accuracy: 38.9%]
# [86 Best Individual - Fitness: 3.73198, Accuracy: 38.9%]
# [87 Best Individual - Fitness: 3.77325, Accuracy: 38.6%]
# [88 Best Individual - Fitness: 3.77325, Accuracy: 38.6%]
# [89 Best Individual - Fitness: 3.77325, Accuracy: 38.6%]
# [90 Best Individual - Fitness: 3.77325, Accuracy: 38.6%]
# [91 Best Individual - Fitness: 3.77325, Accuracy: 38.6%]
# [92 Best Individual - Fitness: 3.81520, Accuracy: 40.1%]
# [93 Best Individual - Fitness: 3.81520, Accuracy: 40.1%]
# [94 Best Individual - Fitness: 3.81520, Accuracy: 40.1%]
# [95 Best Individual - Fitness: 3.81520, Accuracy: 40.1%]
# [96 Best Individual - Fitness: 3.85686, Accuracy: 39.6%]
# [97 Best Individual - Fitness: 3.85686, Accuracy: 39.6%]
# [98 Best Individual - Fitness: 3.85686, Accuracy: 39.6%]
# [99 Best Individual - Fitness: 3.86663, Accuracy: 42.6%]
# [100 Best Individual - Fitness: 3.86663, Accuracy: 42.6%]
# [101 Best Individual - Fitness: 3.88467, Accuracy: 38.6%]
# [102 Best Individual - Fitness: 3.88467, Accuracy: 38.6%]
# [103 Best Individual - Fitness: 3.89657, Accuracy: 41.3%]
# [104 Best Individual - Fitness: 3.90184, Accuracy: 43.9%]
# [105 Best Individual - Fitness: 3.90184, Accuracy: 43.9%]
# [106 Best Individual - Fitness: 3.92716, Accuracy: 40.1%]
# [107 Best Individual - Fitness: 3.92716, Accuracy: 40.1%]
# [108 Best Individual - Fitness: 3.95366, Accuracy: 46.6%]
# [109 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [110 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [111 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [112 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [113 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [114 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [115 Best Individual - Fitness: 4.02944, Accuracy: 47.4%]
# [116 Best Individual - Fitness: 4.05821, Accuracy: 48.5%]
# [117 Best Individual - Fitness: 4.12996, Accuracy: 44.5%]
# [118 Best Individual - Fitness: 4.12996, Accuracy: 44.5%]
# [119 Best Individual - Fitness: 4.12996, Accuracy: 44.5%]
# [120 Best Individual - Fitness: 4.21104, Accuracy: 44.6%]
# [121 Best Individual - Fitness: 4.21104, Accuracy: 44.6%]
# [122 Best Individual - Fitness: 4.21104, Accuracy: 44.6%]
# [123 Best Individual - Fitness: 4.21104, Accuracy: 44.6%]
# [124 Best Individual - Fitness: 4.21104, Accuracy: 44.6%]
# [125 Best Individual - Fitness: 4.25653, Accuracy: 47.4%]
# [126 Best Individual - Fitness: 4.25653, Accuracy: 47.4%]
# [127 Best Individual - Fitness: 4.25653, Accuracy: 47.4%]
# [128 Best Individual - Fitness: 4.28552, Accuracy: 41.5%]
# [129 Best Individual - Fitness: 4.28552, Accuracy: 41.5%]
# [130 Best Individual - Fitness: 4.31452, Accuracy: 45.1%]
# [131 Best Individual - Fitness: 4.31452, Accuracy: 45.1%]
# [132 Best Individual - Fitness: 4.31452, Accuracy: 45.1%]
# [133 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [134 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [135 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [136 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [137 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [138 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [139 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [140 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [141 Best Individual - Fitness: 4.50788, Accuracy: 58.2%]
# [142 Best Individual - Fitness: 4.53855, Accuracy: 50.0%]
# [143 Best Individual - Fitness: 4.53855, Accuracy: 50.0%]
# [144 Best Individual - Fitness: 4.53855, Accuracy: 50.0%]
# [145 Best Individual - Fitness: 4.53898, Accuracy: 55.7%]
# [146 Best Individual - Fitness: 4.55703, Accuracy: 54.6%]
# [147 Best Individual - Fitness: 4.62908, Accuracy: 51.3%]
# [148 Best Individual - Fitness: 4.62908, Accuracy: 51.3%]
# [149 Best Individual - Fitness: 4.63142, Accuracy: 51.0%]
# [150 Best Individual - Fitness: 4.63666, Accuracy: 50.5%]
# [151 Best Individual - Fitness: 4.63666, Accuracy: 50.5%]
# [152 Best Individual - Fitness: 4.72695, Accuracy: 49.2%]
# [153 Best Individual - Fitness: 4.72695, Accuracy: 49.2%]
# [154 Best Individual - Fitness: 4.72695, Accuracy: 49.2%]
# [155 Best Individual - Fitness: 4.72695, Accuracy: 49.2%]
# [156 Best Individual - Fitness: 4.72695, Accuracy: 49.2%]
# [157 Best Individual - Fitness: 4.72695, Accuracy: 49.2%]
# [158 Best Individual - Fitness: 4.72711, Accuracy: 52.4%]
# [159 Best Individual - Fitness: 4.72711, Accuracy: 52.4%]
# [160 Best Individual - Fitness: 4.72906, Accuracy: 49.5%]
# [161 Best Individual - Fitness: 4.86859, Accuracy: 58.5%]
# [162 Best Individual - Fitness: 4.86859, Accuracy: 58.5%]
# [163 Best Individual - Fitness: 4.87208, Accuracy: 57.0%]
# [164 Best Individual - Fitness: 4.87208, Accuracy: 57.0%]
# [165 Best Individual - Fitness: 4.99715, Accuracy: 57.4%]
# [166 Best Individual - Fitness: 4.99715, Accuracy: 57.4%]
# [167 Best Individual - Fitness: 5.00564, Accuracy: 58.4%]
# [168 Best Individual - Fitness: 5.13888, Accuracy: 60.7%]
# [169 Best Individual - Fitness: 5.13888, Accuracy: 60.7%]
# [170 Best Individual - Fitness: 5.13888, Accuracy: 60.7%]
# [171 Best Individual - Fitness: 5.13888, Accuracy: 60.7%]
# [172 Best Individual - Fitness: 5.17807, Accuracy: 61.4%]
# [173 Best Individual - Fitness: 5.17807, Accuracy: 61.4%]
# [174 Best Individual - Fitness: 5.17807, Accuracy: 61.4%]
# [175 Best Individual - Fitness: 5.17807, Accuracy: 61.4%]
# [176 Best Individual - Fitness: 5.17807, Accuracy: 61.4%]
# [177 Best Individual - Fitness: 5.19750, Accuracy: 63.4%]
# [178 Best Individual - Fitness: 5.19750, Accuracy: 63.4%]
# [179 Best Individual - Fitness: 5.19750, Accuracy: 63.4%]
# [180 Best Individual - Fitness: 5.31952, Accuracy: 60.2%]
# [181 Best Individual - Fitness: 5.31952, Accuracy: 60.2%]
# [182 Best Individual - Fitness: 5.31952, Accuracy: 60.2%]
# [183 Best Individual - Fitness: 5.31952, Accuracy: 60.2%]
# [184 Best Individual - Fitness: 5.32252, Accuracy: 61.4%]
# [185 Best Individual - Fitness: 5.34409, Accuracy: 65.2%]
# [186 Best Individual - Fitness: 5.41041, Accuracy: 63.4%]
# [187 Best Individual - Fitness: 5.41041, Accuracy: 63.4%]
# [188 Best Individual - Fitness: 5.41041, Accuracy: 63.4%]
# [189 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [190 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [191 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [192 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [193 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [194 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [195 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [196 Best Individual - Fitness: 5.57642, Accuracy: 67.7%]
# [197 Best Individual - Fitness: 5.70848, Accuracy: 67.9%]
# [198 Best Individual - Fitness: 5.70848, Accuracy: 67.9%]
# [199 Best Individual - Fitness: 5.78685, Accuracy: 69.3%]
# [200 Best Individual - Fitness: 5.78685, Accuracy: 69.3%]
# [201 Best Individual - Fitness: 5.78685, Accuracy: 69.3%]
# [202 Best Individual - Fitness: 5.78685, Accuracy: 69.3%]
# [203 Best Individual - Fitness: 5.78685, Accuracy: 69.3%]
# [204 Best Individual - Fitness: 5.78795, Accuracy: 68.2%]
# [205 Best Individual - Fitness: 5.78795, Accuracy: 68.2%]
# [206 Best Individual - Fitness: 5.78795, Accuracy: 68.2%]
# [207 Best Individual - Fitness: 5.78795, Accuracy: 68.2%]
# [208 Best Individual - Fitness: 5.78795, Accuracy: 68.2%]
# [209 Best Individual - Fitness: 5.91940, Accuracy: 67.8%]
# [210 Best Individual - Fitness: 5.91940, Accuracy: 67.8%]
# [211 Best Individual - Fitness: 5.92963, Accuracy: 70.7%]
# [212 Best Individual - Fitness: 5.92963, Accuracy: 70.7%]
# [213 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [214 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [215 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [216 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [217 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [218 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [219 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [220 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [221 Best Individual - Fitness: 6.13483, Accuracy: 71.2%]
# [222 Best Individual - Fitness: 6.23715, Accuracy: 67.2%]
# [223 Best Individual - Fitness: 6.23715, Accuracy: 67.2%]
# [224 Best Individual - Fitness: 6.23715, Accuracy: 67.2%]
# [225 Best Individual - Fitness: 6.23715, Accuracy: 67.2%]
# [226 Best Individual - Fitness: 6.23715, Accuracy: 67.2%]
# [227 Best Individual - Fitness: 6.32048, Accuracy: 69.9%]
# [228 Best Individual - Fitness: 6.32048, Accuracy: 69.9%]
# [229 Best Individual - Fitness: 6.32048, Accuracy: 69.9%]
# [230 Best Individual - Fitness: 6.32048, Accuracy: 69.9%]
# [231 Best Individual - Fitness: 6.40240, Accuracy: 67.7%]
# [232 Best Individual - Fitness: 6.40240, Accuracy: 67.7%]
# [233 Best Individual - Fitness: 6.51803, Accuracy: 71.6%]
# [234 Best Individual - Fitness: 6.51803, Accuracy: 71.6%]
# [235 Best Individual - Fitness: 6.51803, Accuracy: 71.6%]
# [236 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [237 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [238 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [239 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [240 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [241 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [242 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [243 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [244 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [245 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [246 Best Individual - Fitness: 6.92921, Accuracy: 72.6%]
# [247 Best Individual - Fitness: 6.98763, Accuracy: 72.8%]
# [248 Best Individual - Fitness: 7.06711, Accuracy: 73.9%]
# [249 Best Individual - Fitness: 7.12710, Accuracy: 73.3%]
# [250 Best Individual - Fitness: 7.12710, Accuracy: 73.3%]
# [251 Best Individual - Fitness: 7.12710, Accuracy: 73.3%]
# [252 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [253 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [254 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [255 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [256 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [257 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [258 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [259 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [260 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [261 Best Individual - Fitness: 7.43327, Accuracy: 76.4%]
# [262 Best Individual - Fitness: 7.66992, Accuracy: 76.6%]
# [263 Best Individual - Fitness: 7.66992, Accuracy: 76.6%]
# [264 Best Individual - Fitness: 7.66992, Accuracy: 76.6%]
# [265 Best Individual - Fitness: 7.66992, Accuracy: 76.6%]
# [266 Best Individual - Fitness: 7.66992, Accuracy: 76.6%]
# [267 Best Individual - Fitness: 7.66992, Accuracy: 76.6%]
# [268 Best Individual - Fitness: 7.72748, Accuracy: 78.6%]
# [269 Best Individual - Fitness: 7.75299, Accuracy: 77.4%]
# [270 Best Individual - Fitness: 7.75299, Accuracy: 77.4%]
# [271 Best Individual - Fitness: 7.90193, Accuracy: 75.9%]
# [272 Best Individual - Fitness: 7.98829, Accuracy: 75.7%]
# [273 Best Individual - Fitness: 7.98829, Accuracy: 75.7%]
# [274 Best Individual - Fitness: 8.25099, Accuracy: 77.8%]
# [275 Best Individual - Fitness: 8.25099, Accuracy: 77.8%]
# [276 Best Individual - Fitness: 8.25099, Accuracy: 77.8%]
# [277 Best Individual - Fitness: 8.25099, Accuracy: 77.8%]
# [278 Best Individual - Fitness: 8.25099, Accuracy: 77.8%]
# [279 Best Individual - Fitness: 8.34167, Accuracy: 78.7%]
# [280 Best Individual - Fitness: 8.34167, Accuracy: 78.7%]
# [281 Best Individual - Fitness: 8.34167, Accuracy: 78.7%]
# [282 Best Individual - Fitness: 8.34167, Accuracy: 78.7%]
# [283 Best Individual - Fitness: 8.54540, Accuracy: 80.0%]
# [284 Best Individual - Fitness: 8.54540, Accuracy: 80.0%]
# [285 Best Individual - Fitness: 8.54540, Accuracy: 80.0%]
# [286 Best Individual - Fitness: 8.68136, Accuracy: 80.4%]
# [287 Best Individual - Fitness: 8.68136, Accuracy: 80.4%]
# [288 Best Individual - Fitness: 8.68136, Accuracy: 80.4%]
# [289 Best Individual - Fitness: 8.83897, Accuracy: 78.9%]
# [290 Best Individual - Fitness: 8.83897, Accuracy: 78.9%]
# [291 Best Individual - Fitness: 8.83897, Accuracy: 78.9%]
# [292 Best Individual - Fitness: 8.83897, Accuracy: 78.9%]
# [293 Best Individual - Fitness: 8.83897, Accuracy: 78.9%]
# [294 Best Individual - Fitness: 8.83897, Accuracy: 78.9%]
# [295 Best Individual - Fitness: 9.04736, Accuracy: 81.1%]
# [296 Best Individual - Fitness: 9.04736, Accuracy: 81.1%]
# [297 Best Individual - Fitness: 9.04736, Accuracy: 81.1%]
# [298 Best Individual - Fitness: 9.04736, Accuracy: 81.1%]
# [299 Best Individual - Fitness: 9.04736, Accuracy: 81.1%]
# [300 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [301 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [302 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [303 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [304 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [305 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [306 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [307 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [308 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [309 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [310 Best Individual - Fitness: 9.39314, Accuracy: 81.1%]
# [311 Best Individual - Fitness: 9.54542, Accuracy: 79.4%]
# [312 Best Individual - Fitness: 10.04108, Accuracy: 84.0%]
# [313 Best Individual - Fitness: 10.04108, Accuracy: 84.0%]
# [314 Best Individual - Fitness: 10.04108, Accuracy: 84.0%]
# [315 Best Individual - Fitness: 10.04108, Accuracy: 84.0%]
# [316 Best Individual - Fitness: 10.04108, Accuracy: 84.0%]
# [317 Best Individual - Fitness: 10.09575, Accuracy: 84.2%]
# [318 Best Individual - Fitness: 10.09575, Accuracy: 84.2%]
# [319 Best Individual - Fitness: 10.09575, Accuracy: 84.2%]
# [320 Best Individual - Fitness: 10.09575, Accuracy: 84.2%]
# [321 Best Individual - Fitness: 10.09575, Accuracy: 84.2%]
# [322 Best Individual - Fitness: 10.14061, Accuracy: 82.9%]
# [323 Best Individual - Fitness: 10.14061, Accuracy: 82.9%]
# [324 Best Individual - Fitness: 10.14061, Accuracy: 82.9%]
# [325 Best Individual - Fitness: 10.14061, Accuracy: 82.9%]
# [326 Best Individual - Fitness: 10.14061, Accuracy: 82.9%]
# [327 Best Individual - Fitness: 10.32171, Accuracy: 82.1%]
# [328 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [329 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [330 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [331 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [332 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [333 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [334 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [335 Best Individual - Fitness: 10.45370, Accuracy: 81.9%]
# [336 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [337 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [338 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [339 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [340 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [341 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [342 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [343 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [344 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [345 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [346 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [347 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [348 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [349 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [350 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [351 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [352 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [353 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [354 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [355 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [356 Best Individual - Fitness: 10.97355, Accuracy: 83.5%]
# [357 Best Individual - Fitness: 11.09068, Accuracy: 83.4%]
# [358 Best Individual - Fitness: 11.09068, Accuracy: 83.4%]
# [359 Best Individual - Fitness: 11.36745, Accuracy: 84.3%]
# [360 Best Individual - Fitness: 11.36745, Accuracy: 84.3%]
# [361 Best Individual - Fitness: 11.36745, Accuracy: 84.3%]
# [362 Best Individual - Fitness: 11.36745, Accuracy: 84.3%]
# [363 Best Individual - Fitness: 11.45949, Accuracy: 84.0%]
# [364 Best Individual - Fitness: 11.45949, Accuracy: 84.0%]
# [365 Best Individual - Fitness: 11.45949, Accuracy: 84.0%]
# [366 Best Individual - Fitness: 11.45949, Accuracy: 84.0%]
# [367 Best Individual - Fitness: 11.45949, Accuracy: 84.0%]
# [368 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [369 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [370 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [371 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [372 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [373 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [374 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [375 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [376 Best Individual - Fitness: 11.65053, Accuracy: 85.2%]
# [377 Best Individual - Fitness: 11.66752, Accuracy: 84.6%]
# [378 Best Individual - Fitness: 12.08226, Accuracy: 85.9%]
# [379 Best Individual - Fitness: 12.08226, Accuracy: 85.9%]
# [380 Best Individual - Fitness: 12.08226, Accuracy: 85.9%]
# [381 Best Individual - Fitness: 12.08226, Accuracy: 85.9%]
# [382 Best Individual - Fitness: 12.08226, Accuracy: 85.9%]
# [383 Best Individual - Fitness: 12.08226, Accuracy: 85.9%]
# [384 Best Individual - Fitness: 12.13371, Accuracy: 84.7%]
# [385 Best Individual - Fitness: 12.13371, Accuracy: 84.7%]
# [386 Best Individual - Fitness: 12.13371, Accuracy: 84.7%]
# [387 Best Individual - Fitness: 12.13371, Accuracy: 84.7%]
# [388 Best Individual - Fitness: 12.17207, Accuracy: 84.2%]
# [389 Best Individual - Fitness: 12.17207, Accuracy: 84.2%]
# [390 Best Individual - Fitness: 12.17207, Accuracy: 84.2%]
# [391 Best Individual - Fitness: 12.17207, Accuracy: 84.2%]
# [392 Best Individual - Fitness: 12.28232, Accuracy: 85.8%]
# [393 Best Individual - Fitness: 12.28232, Accuracy: 85.8%]
# [394 Best Individual - Fitness: 12.28232, Accuracy: 85.8%]
# [395 Best Individual - Fitness: 12.28232, Accuracy: 85.8%]
# [396 Best Individual - Fitness: 12.28232, Accuracy: 85.8%]
# [397 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [398 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [399 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [400 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [401 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [402 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [403 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [404 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [405 Best Individual - Fitness: 12.53195, Accuracy: 86.2%]
# [406 Best Individual - Fitness: 12.86962, Accuracy: 85.5%]
# [407 Best Individual - Fitness: 12.86962, Accuracy: 85.5%]
# [408 Best Individual - Fitness: 12.86962, Accuracy: 85.5%]
# [409 Best Individual - Fitness: 12.86962, Accuracy: 85.5%]
# [410 Best Individual - Fitness: 12.86962, Accuracy: 85.5%]
# [411 Best Individual - Fitness: 12.86962, Accuracy: 85.5%]
# [412 Best Individual - Fitness: 13.08086, Accuracy: 86.5%]
# [413 Best Individual - Fitness: 13.31400, Accuracy: 86.3%]
# [414 Best Individual - Fitness: 13.31400, Accuracy: 86.3%]
# [415 Best Individual - Fitness: 13.31400, Accuracy: 86.3%]
# [416 Best Individual - Fitness: 13.31400, Accuracy: 86.3%]
# [417 Best Individual - Fitness: 13.31400, Accuracy: 86.3%]
# [418 Best Individual - Fitness: 13.31400, Accuracy: 86.3%]
# [419 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [420 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [421 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [422 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [423 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [424 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [425 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [426 Best Individual - Fitness: 13.50454, Accuracy: 87.6%]
# [427 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [428 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [429 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [430 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [431 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [432 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [433 Best Individual - Fitness: 13.74511, Accuracy: 88.0%]
# [434 Best Individual - Fitness: 13.77291, Accuracy: 86.2%]
# [435 Best Individual - Fitness: 13.88653, Accuracy: 87.5%]
# [436 Best Individual - Fitness: 13.88653, Accuracy: 87.5%]
# [437 Best Individual - Fitness: 13.88653, Accuracy: 87.5%]
# [438 Best Individual - Fitness: 13.88653, Accuracy: 87.5%]
# [439 Best Individual - Fitness: 13.88653, Accuracy: 87.5%]
# [440 Best Individual - Fitness: 13.88653, Accuracy: 87.5%]
# [441 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [442 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [443 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [444 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [445 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [446 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [447 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [448 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [449 Best Individual - Fitness: 14.42688, Accuracy: 87.8%]
# [450 Best Individual - Fitness: 14.76782, Accuracy: 88.1%]
# [451 Best Individual - Fitness: 14.76782, Accuracy: 88.1%]
# [452 Best Individual - Fitness: 14.76782, Accuracy: 88.1%]
# [453 Best Individual - Fitness: 14.76782, Accuracy: 88.1%]
# [454 Best Individual - Fitness: 14.91320, Accuracy: 87.7%]
# [455 Best Individual - Fitness: 14.91320, Accuracy: 87.7%]
# [456 Best Individual - Fitness: 14.91320, Accuracy: 87.7%]
# [457 Best Individual - Fitness: 14.91320, Accuracy: 87.7%]
# [458 Best Individual - Fitness: 14.91320, Accuracy: 87.7%]
# [459 Best Individual - Fitness: 14.91320, Accuracy: 87.7%]
# [460 Best Individual - Fitness: 15.25164, Accuracy: 88.0%]
# [461 Best Individual - Fitness: 15.25164, Accuracy: 88.0%]
# [462 Best Individual - Fitness: 15.25164, Accuracy: 88.0%]
# [463 Best Individual - Fitness: 15.25164, Accuracy: 88.0%]
# [464 Best Individual - Fitness: 15.29667, Accuracy: 88.8%]
# [465 Best Individual - Fitness: 15.29667, Accuracy: 88.8%]
# [466 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [467 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [468 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [469 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [470 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [471 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [472 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [473 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [474 Best Individual - Fitness: 15.37775, Accuracy: 89.6%]
# [475 Best Individual - Fitness: 15.52293, Accuracy: 89.6%]
# [476 Best Individual - Fitness: 15.52293, Accuracy: 89.6%]
# [477 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [478 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [479 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [480 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [481 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [482 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [483 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [484 Best Individual - Fitness: 15.91455, Accuracy: 89.5%]
# [485 Best Individual - Fitness: 15.92273, Accuracy: 88.7%]
# [486 Best Individual - Fitness: 15.92273, Accuracy: 88.7%]
# [487 Best Individual - Fitness: 15.92273, Accuracy: 88.7%]
# [488 Best Individual - Fitness: 15.92273, Accuracy: 88.7%]
# [489 Best Individual - Fitness: 16.07814, Accuracy: 88.8%]
# [490 Best Individual - Fitness: 16.07814, Accuracy: 88.8%]
# [491 Best Individual - Fitness: 16.07814, Accuracy: 88.8%]
# [492 Best Individual - Fitness: 16.07814, Accuracy: 88.8%]
# [493 Best Individual - Fitness: 16.07814, Accuracy: 88.8%]
# [494 Best Individual - Fitness: 16.69522, Accuracy: 91.3%]
# [495 Best Individual - Fitness: 16.69522, Accuracy: 91.3%]
# [496 Best Individual - Fitness: 16.69522, Accuracy: 91.3%]
# [497 Best Individual - Fitness: 16.69522, Accuracy: 91.3%]
# [498 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [499 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [500 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [501 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [502 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [503 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [504 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [505 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [506 Best Individual - Fitness: 16.91676, Accuracy: 90.9%]
# [507 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [508 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [509 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [510 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [511 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [512 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [513 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [514 Best Individual - Fitness: 16.96641, Accuracy: 89.3%]
# [515 Best Individual - Fitness: 17.18824, Accuracy: 90.1%]
# [516 Best Individual - Fitness: 17.45662, Accuracy: 90.7%]
# [517 Best Individual - Fitness: 17.45662, Accuracy: 90.7%]
# [518 Best Individual - Fitness: 17.94839, Accuracy: 91.1%]
# [519 Best Individual - Fitness: 17.94839, Accuracy: 91.1%]
# [520 Best Individual - Fitness: 17.94839, Accuracy: 91.1%]
# [521 Best Individual - Fitness: 17.94839, Accuracy: 91.1%]
# [522 Best Individual - Fitness: 17.94839, Accuracy: 91.1%]
# [523 Best Individual - Fitness: 17.94839, Accuracy: 91.1%]
# [524 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [525 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [526 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [527 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [528 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [529 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [530 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [531 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [532 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [533 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [534 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [535 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [536 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [537 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [538 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [539 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [540 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [541 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [542 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [543 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [544 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [545 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [546 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [547 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [548 Best Individual - Fitness: 18.75525, Accuracy: 91.3%]
# [549 Best Individual - Fitness: 19.04297, Accuracy: 91.0%]
# [550 Best Individual - Fitness: 19.04297, Accuracy: 91.0%]
# [551 Best Individual - Fitness: 19.04297, Accuracy: 91.0%]
# [552 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [553 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [554 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [555 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [556 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [557 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [558 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [559 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [560 Best Individual - Fitness: 19.40457, Accuracy: 91.2%]
# [561 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [562 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [563 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [564 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [565 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [566 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [567 Best Individual - Fitness: 19.41409, Accuracy: 91.6%]
# [568 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [569 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [570 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [571 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [572 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [573 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [574 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [575 Best Individual - Fitness: 19.70357, Accuracy: 91.7%]
# [576 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [577 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [578 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [579 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [580 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [581 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [582 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [583 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [584 Best Individual - Fitness: 19.80942, Accuracy: 91.2%]
# [585 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [586 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [587 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [588 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [589 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [590 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [591 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [592 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [593 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [594 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [595 Best Individual - Fitness: 20.10449, Accuracy: 91.6%]
# [596 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [597 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [598 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [599 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [600 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [601 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [602 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [603 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [604 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [605 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [606 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [607 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [608 Best Individual - Fitness: 20.36025, Accuracy: 91.5%]
# [609 Best Individual - Fitness: 20.46599, Accuracy: 92.2%]
# [610 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [611 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [612 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [613 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [614 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [615 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [616 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [617 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [618 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [619 Best Individual - Fitness: 20.69186, Accuracy: 92.3%]
# [620 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [621 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [622 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [623 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [624 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [625 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [626 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [627 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [628 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [629 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [630 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [631 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [632 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [633 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [634 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [635 Best Individual - Fitness: 21.84481, Accuracy: 92.4%]
# [636 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [637 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [638 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [639 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [640 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [641 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [642 Best Individual - Fitness: 21.89070, Accuracy: 92.5%]
# [643 Best Individual - Fitness: 22.30802, Accuracy: 92.5%]
# [644 Best Individual - Fitness: 22.34550, Accuracy: 93.3%]
# [645 Best Individual - Fitness: 22.34550, Accuracy: 93.3%]
# [646 Best Individual - Fitness: 22.34550, Accuracy: 93.3%]
# [647 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [648 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [649 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [650 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [651 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [652 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [653 Best Individual - Fitness: 22.41685, Accuracy: 92.7%]
# [654 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [655 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [656 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [657 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [658 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [659 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [660 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [661 Best Individual - Fitness: 22.60626, Accuracy: 93.0%]
# [662 Best Individual - Fitness: 23.14264, Accuracy: 92.4%]
# [663 Best Individual - Fitness: 23.14264, Accuracy: 92.4%]
# [664 Best Individual - Fitness: 23.14264, Accuracy: 92.4%]
# [665 Best Individual - Fitness: 23.14264, Accuracy: 92.4%]
# [666 Best Individual - Fitness: 23.43967, Accuracy: 92.7%]
# [667 Best Individual - Fitness: 23.43967, Accuracy: 92.7%]
# [668 Best Individual - Fitness: 23.43967, Accuracy: 92.7%]
# [669 Best Individual - Fitness: 23.43967, Accuracy: 92.7%]
# [670 Best Individual - Fitness: 23.43967, Accuracy: 92.7%]
# [671 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [672 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [673 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [674 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [675 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [676 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [677 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [678 Best Individual - Fitness: 23.62247, Accuracy: 92.7%]
# [679 Best Individual - Fitness: 23.88997, Accuracy: 92.1%]
# [680 Best Individual - Fitness: 23.88997, Accuracy: 92.1%]
# [681 Best Individual - Fitness: 23.88997, Accuracy: 92.1%]
# [682 Best Individual - Fitness: 23.88997, Accuracy: 92.1%]
# [683 Best Individual - Fitness: 23.88997, Accuracy: 92.1%]
# [684 Best Individual - Fitness: 24.00766, Accuracy: 92.4%]
# [685 Best Individual - Fitness: 24.00766, Accuracy: 92.4%]
# [686 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [687 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [688 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [689 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [690 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [691 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [692 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [693 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [694 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [695 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [696 Best Individual - Fitness: 24.28070, Accuracy: 92.8%]
# [697 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [698 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [699 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [700 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [701 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [702 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [703 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [704 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [705 Best Individual - Fitness: 24.41982, Accuracy: 93.1%]
# [706 Best Individual - Fitness: 24.43383, Accuracy: 93.0%]
# [707 Best Individual - Fitness: 24.69734, Accuracy: 92.7%]
# [708 Best Individual - Fitness: 24.69734, Accuracy: 92.7%]
# [709 Best Individual - Fitness: 24.69734, Accuracy: 92.7%]
# [710 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [711 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [712 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [713 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [714 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [715 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [716 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [717 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [718 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [719 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [720 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [721 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [722 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [723 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [724 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [725 Best Individual - Fitness: 24.89616, Accuracy: 93.6%]
# [726 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [727 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [728 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [729 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [730 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [731 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [732 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [733 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [734 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [735 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [736 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [737 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [738 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [739 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [740 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [741 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [742 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [743 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [744 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [745 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [746 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [747 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [748 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [749 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [750 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [751 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [752 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [753 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [754 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [755 Best Individual - Fitness: 25.84130, Accuracy: 93.4%]
# [756 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [757 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [758 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [759 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [760 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [761 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [762 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [763 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [764 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [765 Best Individual - Fitness: 25.86147, Accuracy: 93.2%]
# [766 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [767 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [768 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [769 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [770 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [771 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [772 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [773 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [774 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [775 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [776 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [777 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [778 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [779 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [780 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [781 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [782 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [783 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [784 Best Individual - Fitness: 26.65459, Accuracy: 92.4%]
# [785 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [786 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [787 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [788 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [789 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [790 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [791 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [792 Best Individual - Fitness: 26.76062, Accuracy: 93.2%]
# [793 Best Individual - Fitness: 27.65468, Accuracy: 94.2%]
# [794 Best Individual - Fitness: 27.65468, Accuracy: 94.2%]
# [795 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [796 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [797 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [798 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [799 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [800 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [801 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [802 Best Individual - Fitness: 27.80990, Accuracy: 93.9%]
# [803 Best Individual - Fitness: 28.16625, Accuracy: 94.0%]
# [804 Best Individual - Fitness: 28.16625, Accuracy: 94.0%]
# [805 Best Individual - Fitness: 28.16625, Accuracy: 94.0%]
# [806 Best Individual - Fitness: 28.16625, Accuracy: 94.0%]
# [807 Best Individual - Fitness: 28.49504, Accuracy: 94.1%]
# [808 Best Individual - Fitness: 28.49504, Accuracy: 94.1%]
# [809 Best Individual - Fitness: 28.49504, Accuracy: 94.1%]
# ...
# [1045 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1046 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1047 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1048 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1049 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1050 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1051 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1052 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1053 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1054 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1055 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1056 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1057 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1058 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1059 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1060 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1061 Best Individual - Fitness: 38.74886, Accuracy: 95.7%]
# [1062 Best Individual - Fitness: 39.46537, Accuracy: 95.6%]
# [1063 Best Individual - Fitness: 39.46537, Accuracy: 95.6%]
# [1064 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1065 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1066 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1067 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1068 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1069 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1070 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1071 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1072 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1073 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1074 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1075 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1076 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1077 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1078 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1079 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1080 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1081 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1082 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1083 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1084 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1085 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1086 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1087 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1088 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1089 Best Individual - Fitness: 39.81716, Accuracy: 96.0%]
# [1090 Best Individual - Fitness: 40.39854, Accuracy: 96.0%]
# [1091 Best Individual - Fitness: 40.39854, Accuracy: 96.0%]
# [1092 Best Individual - Fitness: 40.56522, Accuracy: 95.9%]
# [1093 Best Individual - Fitness: 40.56522, Accuracy: 95.9%]
# [1094 Best Individual - Fitness: 40.56522, Accuracy: 95.9%]
# [1095 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1096 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1097 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1098 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1099 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1100 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1101 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1102 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1103 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1104 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1105 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1106 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1107 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1108 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1109 Best Individual - Fitness: 41.53572, Accuracy: 95.7%]
# [1110 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1111 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1112 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1113 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1114 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1115 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1116 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1117 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1118 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1119 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1120 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1121 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1122 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1123 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1124 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1125 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1126 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1127 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1128 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1129 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1130 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1131 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1132 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1133 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1134 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1135 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1136 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1137 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1138 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1139 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1140 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1141 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1142 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1143 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1144 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1145 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1146 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1147 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1148 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1149 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1150 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1151 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1152 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1153 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1154 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1155 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1156 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1157 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1158 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1159 Best Individual - Fitness: 42.34173, Accuracy: 96.5%]
# [1160 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1161 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1162 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1163 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1164 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1165 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1166 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1167 Best Individual - Fitness: 42.88132, Accuracy: 96.3%]
# [1168 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1169 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1170 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1171 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1172 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1173 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1174 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1175 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1176 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1177 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1178 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1179 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1180 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1181 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1182 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1183 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1184 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1185 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1186 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1187 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1188 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1189 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1190 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1191 Best Individual - Fitness: 42.94388, Accuracy: 96.4%]
# [1192 Best Individual - Fitness: 42.97674, Accuracy: 96.1%]
# [1193 Best Individual - Fitness: 42.97674, Accuracy: 96.1%]
# [1194 Best Individual - Fitness: 42.97674, Accuracy: 96.1%]
# [1195 Best Individual - Fitness: 42.97674, Accuracy: 96.1%]
# [1196 Best Individual - Fitness: 42.97674, Accuracy: 96.1%]
# [1197 Best Individual - Fitness: 42.97674, Accuracy: 96.1%]
# [1198 Best Individual - Fitness: 43.10997, Accuracy: 96.4%]
# [1199 Best Individual - Fitness: 43.10997, Accuracy: 96.4%]
# [1200 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1201 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1202 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1203 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1204 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1205 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1206 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1207 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1208 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1209 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1210 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1211 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1212 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1213 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1214 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1215 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1216 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1217 Best Individual - Fitness: 43.38285, Accuracy: 96.5%]
# [1218 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1219 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1220 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1221 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1222 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1223 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1224 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1225 Best Individual - Fitness: 43.43087, Accuracy: 96.4%]
# [1226 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1227 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1228 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1229 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1230 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1231 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1232 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1233 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1234 Best Individual - Fitness: 43.76304, Accuracy: 96.2%]
# [1235 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1236 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1237 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1238 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1239 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1240 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1241 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1242 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1243 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1244 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1245 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1246 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1247 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1248 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1249 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1250 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1251 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1252 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1253 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1254 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1255 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1256 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1257 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1258 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1259 Best Individual - Fitness: 44.39860, Accuracy: 96.3%]
# [1260 Best Individual - Fitness: 45.59658, Accuracy: 96.9%]
# [1261 Best Individual - Fitness: 45.59658, Accuracy: 96.9%]
# [1262 Best Individual - Fitness: 45.59658, Accuracy: 96.9%]
# [1263 Best Individual - Fitness: 45.59658, Accuracy: 96.9%]
# [1264 Best Individual - Fitness: 45.59658, Accuracy: 96.9%]
# [1265 Best Individual - Fitness: 45.59658, Accuracy: 96.9%]
# [1266 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1267 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1268 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1269 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1270 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1271 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1272 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1273 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1274 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1275 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1276 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1277 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1278 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1279 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1280 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1281 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1282 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1283 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1284 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1285 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1286 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1287 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1288 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1289 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1290 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1291 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1292 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1293 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1294 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1295 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1296 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1297 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1298 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1299 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1300 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1301 Best Individual - Fitness: 46.02445, Accuracy: 96.6%]
# [1302 Best Individual - Fitness: 46.50209, Accuracy: 96.5%]
# [1303 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1304 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1305 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1306 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1307 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1308 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1309 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
# [1310 Best Individual - Fitness: 47.04550, Accuracy: 96.1%]
